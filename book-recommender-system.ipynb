# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('book2.csv')
users = pd.read_csv('user2.csv')
ratings = pd.read_csv('rating2.csv')
# Out:
# C:\Users\sarit\AppData\Local\Temp\ipykernel_5388\2108492875.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('book2.csv')
# C:\Users\sarit\AppData\Local\Temp\ipykernel_5388\2108492875.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   users = pd.read_csv('user2.csv')

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User  User-ID                                         Book-Title  Rating
# 0   1.0   276725                                Classical Mythology       0
# 1   2.0   276726                                       Clara Callan       5
# 2   3.0   276727                               Decision in Normandy       0
# 3   4.0   276729  Flu: The Story of the Great Influenza Pandemic...       3
# 4   5.0   276729                             The Mummies of Urumchi       6

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726   155061224            5
# 2   276727   446520802            0
# 3   276729  052165615X            3
# 4   276729   521795028            6

# %%
books.head()
# Out:
#         ISBN                                         Book-Title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1048575, 3)
# (1048575, 4)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User          769717
# User-ID            0
# Book-Title    777215
# Rating             0
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(146)

# %%
users.duplicated().sum()
# Out:
# np.int64(630218)

# %%
ratings_with_name = ratings.merge(books,on='ISBN')
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276725  034545104X            0
# 1        276726   155061224            5
# 2        276727   446520802            0
# 3        276729  052165615X            3
# 4        276729   521795028            6
# ...         ...         ...          ...
# 941107   250764   451410777            0
# 941108   250764   452264464            8
# 941109   250764  048623715X            0
# 941110   250764   486256588            0
# 941111   250764   515069434            0
#
#                                                Book-Title      Book-Author  \
# 0                                    Flesh Tones: A Novel       M. J. Rose
# 1                                        Rites of Passage       Judith Rae
# 2                                            The Notebook  Nicholas Sparks
# 3                                          Help!: Level 1    Philip Prowse
# 4       The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
# ...

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'Number-Of-Rating'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  Number-Of-Rating
# 0        A Light in the Storm: The Civil War Diary of ...                 4
# 1                                   Always Have Popsicles                 1
# 2                    Apple Magic (The Collector's series)                 1
# 3        Beyond IBM: Leadership Marketing and Finance ...                 1
# 4        Clifford Visita El Hospital (Clifford El Gran...                 1
# ...                                                   ...               ...
# 230215                                 Ã?Â?l- Connection.                 1
# 230216                                      Ã?Â?lpiraten.                 2
# 230217                     Ã?Â?rger mit Produkt X. Roman.                 4
# 230218                              Ã?Â?stlich der Berge.                 2
# 230219                                  Ã?Â?thique en toc                 2
#
# [230220 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df.rename(columns={'Book-Rating':'Average-Rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  Average-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            2.25
# 1                                   Always Have Popsicles            0.00
# 2                    Apple Magic (The Collector's series)            0.00
# 3        Beyond IBM: Leadership Marketing and Finance ...            0.00
# 4        Clifford Visita El Hospital (Clifford El Gran...            0.00
# ...                                                   ...             ...
# 230215                                 Ã?Â?l- Connection.            0.00
# 230216                                      Ã?Â?lpiraten.            0.00
# 230217                     Ã?Â?rger mit Produkt X. Roman.            5.25
# 230218                              Ã?Â?stlich der Berge.            4.00
# 230219                                  Ã?Â?thique en toc            4.00
#
# [230220 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  Number-Of-Rating  \
# 0        A Light in the Storm: The Civil War Diary of ...                 4
# 1                                   Always Have Popsicles                 1
# 2                    Apple Magic (The Collector's series)                 1
# 3        Beyond IBM: Leadership Marketing and Finance ...                 1
# 4        Clifford Visita El Hospital (Clifford El Gran...                 1
# ...                                                   ...               ...
# 230215                                 Ã?Â?l- Connection.                 1
# 230216                                      Ã?Â?lpiraten.                 2
# 230217                     Ã?Â?rger mit Produkt X. Roman.                 4
# 230218                              Ã?Â?stlich der Berge.                 2
# 230219                                  Ã?Â?thique en toc                 2
#
#         Average-Rating
# 0                 2.25
# ...

# %%
popular_df = popular_df[popular_df['Number-Of-Rating']>=100].sort_values('Average-Rating',ascending=False).head(500)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','Number-Of-Rating','Average-Rating']]

# %%
popular_df
# Out:
#                                              Book-Title  \
# 0          Harry Potter and the Goblet of Fire (Book 4)
# 2     Harry Potter and the Prisoner of Azkaban (Book 3)
# 5        Harry Potter and the Sorcerer's Stone (Book 1)
# 9                                     The Little Prince
# 14    Harry Potter and the Order of the Phoenix (Boo...
# ...                                                 ...
# 1635                          The Liar's Club: A Memoir
# 1637                Jack &amp; Jill (Alex Cross Novels)
# 1638                                          Strangers
# 1644                                  J Is for Judgment
# 1645                                        Mortal Prey
#
#                     Book-Author  \
# 0                 J. K. Rowling
# 2                 J. K. Rowling
# 5                 J. K. Rowling
# 9     Antoine de Saint-ExupÃ©ry
# 14                J. K. Rowling
# ...                         ...
# 1635                  Mary Karr
# ...

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 100
experienced_users = x[x].index

# %%
experienced_users
# Out:
# Index([   254,    507,    882,   1424,   1435,   1733,   1903,   2033,   2110,
#          2276,
#        ...
#        250510, 250645, 250709, 250764, 277427, 277478, 277639, 278137, 278188,
#        278418],
#       dtype='int64', name='User-ID', length=1503)

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(experienced_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (922, 922)

# %%
def recommend(book_name):
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.LZZZZZZZ.jpg'],
#  ["Slaughterhouse Five or the Children's Crusade: A Duty Dance With Death",
#   'Kurt Vonnegut',
#   'http://images.amazon.com/images/P/0440180295.01.LZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.LZZZZZZZ.jpg'],
#  ['Word Freak: Heartbreak, Triumph, Genius, and Obsession in the World of Competitive Scrabble Players',
#   'Stefan Fatsis',
#   'http://images.amazon.com/images/P/0142002267.01.LZZZZZZZ.jpg']]

# %%
pt.index[545]
# Out:
# 'Secrets'

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354   449906736      Flashpoints: Promise and Peril in a New World
# 271356   525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358   192126040                        Republic (World's Classics)
# 271359   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
new_ratings = final_ratings
def change_url(param):
    if isinstance(param,str):
        param = param.replace('http','https')
        return param
    new_ratings['new_Image-URL-M'] = new_ratings['Image-URL-M'].apply(change_url)
